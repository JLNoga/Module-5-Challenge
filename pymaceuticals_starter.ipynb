# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="right")
merge_df
# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        f932     Ketapril    Male          15          29          0
# 2        g107     Ketapril  Female           2          29          0
# 3        a457     Ketapril  Female          11          30          0
# 4        c819     Ketapril    Male          21          25          0
# ...       ...          ...     ...         ...         ...        ...
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
# 1890     p438     Ceftamin  Female          11          26         45
# 1891     x773      Placebo  Female          21          30         45
# 1892     b879     Stelasyn  Female           4          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="right")

# Display the data table for preview
merge_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     b128    Capomulin  Female           9          22          0
# 1     f932     Ketapril    Male          15          29          0
# 2     g107     Ketapril  Female           2          29          0
# 3     a457     Ketapril  Female          11          30          0
# 4     c819     Ketapril    Male          21          25          0
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                45.0                 0
# 1                45.0                 0
# 2                45.0                 0
# 3                45.0                 0
# 4                45.0                 0

# %%
# Checking the number of mice.
merge_df.nunique()["Mouse ID"]
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
merge_df["Mouse ID"].value_counts()
# Out:
# g989    13
# b128    10
# q787    10
# s337    10
# q511    10
#         ..
# f932     1
# b447     1
# u153     1
# t573     1
# o848     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_merge_df = merge_df.loc[merge_df["Mouse ID"] == "g989"]
dup_merge_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 107      g989     Propriva  Female          21          26          0
# 137      g989     Propriva  Female          21          26          0
# 329      g989     Propriva  Female          21          26          5
# 360      g989     Propriva  Female          21          26          5
# 620      g989     Propriva  Female          21          26         10
# 681      g989     Propriva  Female          21          26         10
# 815      g989     Propriva  Female          21          26         15
# 869      g989     Propriva  Female          21          26         15
# 950      g989     Propriva  Female          21          26         20
# 1111     g989     Propriva  Female          21          26         20
# 1195     g989     Propriva  Female          21          26         25
# 1380     g989     Propriva  Female          21          26         30
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
filter_merge_df = merge_df[merge_df['Mouse ID'] != 'g989']
filter_merge_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        f932     Ketapril    Male          15          29          0
# 2        g107     Ketapril  Female           2          29          0
# 3        a457     Ketapril  Female          11          30          0
# 4        c819     Ketapril    Male          21          25          0
# ...       ...          ...     ...         ...         ...        ...
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
# 1890     p438     Ceftamin  Female          11          26         45
# 1891     x773      Placebo  Female          21          30         45
# 1892     b879     Stelasyn  Female           4          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
filter_merge_df.columns
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
# Checking the number of mice in the clean DataFrame.
filter_merge_df["Mouse ID"].value_counts()
# Out:
# b128    10
# q787    10
# c559    10
# s337    10
# q511    10
#         ..
# n482     1
# t573     1
# f932     1
# o848     1
# x336     1
# Name: Mouse ID, Length: 248, dtype: int64

# %%
filter_merge_df["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
filter_merge_df_mean = filter_merge_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
filter_merge_df_mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
filter_merge_df_median = filter_merge_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
filter_merge_df_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
filter_merge_df_var = filter_merge_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
filter_merge_df_var
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     43.852013
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
filter_merge_df_dev = filter_merge_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
filter_merge_df_dev
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.622085
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
filter_merge_df_stderr = filter_merge_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
filter_merge_df_stderr
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.544332
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
summary_stats_gb = pd.DataFrame({"Mean Tumor Volume": filter_merge_df_mean,
                                "Median Tumor Volume": filter_merge_df_median,
                                "Tumor Volume Variance": filter_merge_df_var,
                                "Tumor Volume Std. Dev.": filter_merge_df_dev,
                                "Tumor Volume Std. Err.": filter_merge_df_stderr})
summary_stats_gb
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
summary_stats_agg_df = filter_merge_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]})
summary_stats_agg_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# %%
mouse_bar_df = filter_merge_df.groupby(['Drug Regimen']).count()
mouse_bar_df
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           148  148         148         148        148
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# ...

# %%
mice_bar = mouse_bar_df.plot.bar(y='Mouse ID', rot=90)
mice_bar
# Out:
# <AxesSubplot:xlabel='Drug Regimen'>

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

# %%
mouse_bar_df['Mouse ID'].plot(kind="bar")
plt.xticks(rotation=90, horizontalalignment="center")
plt.title("Mice Tested per Drug")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
# Out:
# Text(0, 0.5, 'Number of Mice Tested')

# %%
mouse_pie_df = filter_merge_df.groupby(['Sex']).count()
mouse_pie_df
# Out:
#         Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# Sex
# Female       922           922         922         922        922
# Male         958           958         958         958        958
#
#         Tumor Volume (mm3)  Metastatic Sites
# Sex
# Female                 922               922
# Male                   958               958

# %%
mice_pie = mouse_pie_df.plot.pie(y='Mouse ID', figsize=(3,3), legend=False, ylabel="Sex")
mice_pie
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# %%
mouse_pie_df['Mouse ID'].plot(kind="pie")
plt.ylabel("Sex")
# Out:
# Text(0, 0.5, 'Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# %%
filter_merge_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        f932     Ketapril    Male          15          29          0
# 2        g107     Ketapril  Female           2          29          0
# 3        a457     Ketapril  Female          11          30          0
# 4        c819     Ketapril    Male          21          25          0
# ...       ...          ...     ...         ...         ...        ...
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
# 1890     p438     Ceftamin  Female          11          26         45
# 1891     x773      Placebo  Female          21          30         45
# 1892     b879     Stelasyn  Female           4          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Start by getting the last (greatest) timepoint for each mouse
timepoint_df = filter_merge_df.groupby(["Mouse ID"]).max()["Timepoint"]
timepoint_df
# Out:
# Mouse ID
# a203    45
# a251    45
# a262    45
# a275    45
# a366    30
#         ..
# z435    10
# z578    45
# z581    45
# z795    45
# z969    45
# Name: Timepoint, Length: 248, dtype: int64

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
timepoint_merge_df = pd.merge(timepoint_df, filter_merge_df, on=["Mouse ID", "Timepoint"], how="left")
timepoint_merge_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# %%
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_0 = []
tumor_vol_1 = []
tumor_vol_2 = []
tumor_vol_3 = []

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
q75, q25 = np.percentile(timepoint_merge_df['Tumor Volume (mm3)'], [75 ,25])
iqr = q75 - q25
    
iqr
# Out:
# 19.177757257500012

# %%
 # Locate the rows which contain mice on each drug and get the tumor volumes
treatment_list_df = timepoint_merge_df.loc[(timepoint_merge_df["Drug Regimen"] == "Capomulin") | (
    timepoint_merge_df["Drug Regimen"] == "Ramicane") | (
    timepoint_merge_df["Drug Regimen"] == "Infubinol") | (
    timepoint_merge_df["Drug Regimen"] == "Ceftamin"), :]
treatment_list_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 3       a275         45     Ceftamin  Female          20          28
# 6       a411         45     Ramicane    Male           3          22
# 7       a444         45     Ramicane  Female          10          25
# ..       ...        ...          ...     ...         ...         ...
# 238     y769         45     Ceftamin  Female           6          27
# 239     y793         45    Capomulin    Male          17          17
# 240     y865         45     Ceftamin    Male          23          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
treatment_list_0 = treatment_list_df.loc[treatment_list_df["Drug Regimen"] == "Capomulin", :]   
treatment_list_0
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 19      b128         45    Capomulin  Female           9          22
# 24      b742         45    Capomulin    Male           7          21
# 61      f966         20    Capomulin    Male          16          17
# 64      g288         45    Capomulin    Male           3          19
# 66      g316         45    Capomulin  Female          22          22
# 80      i557         45    Capomulin  Female           1          24
# 83      i738         45    Capomulin  Female          23          20
# 85      j119         45    Capomulin  Female           7          23
# 87      j246         35    Capomulin  Female          21          21
# 108     l509         45    Capomulin    Male          17          21
# 115     l897         45    Capomulin    Male          17          19
# 121     m601         45    Capomulin    Male          22          17
# 124     m957         45    Capomulin  Female           3          19
# ...

# %%
for row in treatment_list_0:
    tumor_vol_0.append(treatment_list_0["Tumor Volume (mm3)"])
print(tumor_vol_0)
# Out:
# ['I', 'i', 'e', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 'Tumor Volume (mm3)', 19     38.982878
# 24     38.939633
# 61     30.485985
# 64     37.074024
# 66     40.159220
# 80     47.685963
# 83     37.311846
# 85     38.125164
# 87     38.753265
# 108    41.483008
# 115    38.846876
# 121    28.430964
# 124    33.329098
# 162    46.539206
# 163    32.377357
# 169    41.581521
# 174    23.343598
# 180    40.728578
# 183    34.455298
# 192    31.023923
# 204    40.658124
# 208    39.952347
# 220    36.041047
# 226    28.484033
# 239    31.896238
# Name: Tumor Volume (mm3), dtype: float64, 19     38.982878
# 24     38.939633
# 61     30.485985
# 64     37.074024
# 66     40.159220
# 80     47.685963
# 83     37.311846
# 85     38.125164
# 87     38.753265
# 108    41.483008
# 115    38.846876
# 121    28.430964
# 124    33.329098
# 162    46.539206
# 163    32.377357
# ...

# %%
   
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
line_chart = filter_merge_df.loc[filter_merge_df["Mouse ID"] == "l509", :]
line_chart
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 231      l509    Capomulin  Male          17          21          0
# 253      l509    Capomulin  Male          17          21          5
# 539      l509    Capomulin  Male          17          21         10
# 881      l509    Capomulin  Male          17          21         15
# 982      l509    Capomulin  Male          17          21         20
# 1146     l509    Capomulin  Male          17          21         25
# 1414     l509    Capomulin  Male          17          21         30
# 1499     l509    Capomulin  Male          17          21         35
# 1723     l509    Capomulin  Male          17          21         40
# 1771     l509    Capomulin  Male          17          21         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 231            45.000000                 0
# 253            45.851193                 0
# 539            46.759074                 0
# 881            47.488599                 1
# ...

# %%
line_chart.plot.line(x="Timepoint", y="Tumor Volume (mm3)", title="Capomulin Treatment of Mouse l509", 
                     ylabel="Tumor Volume (mm3)", xlabel="Timepoint (days)", legend=False)
# Out:
# <AxesSubplot:title={'center':'Capomulin Treatment of Mouse l509'}, xlabel='Timepoint (days)', ylabel='Tumor Volume (mm3)'>

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %%
filter_merge_df_cap = filter_merge_df.loc[filter_merge_df["Drug Regimen"] == "Capomulin", :]
filter_merge_df_cap
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 226      j246    Capomulin  Female          21          21          0
# 227      r554    Capomulin  Female           8          17          0
# 228      s185    Capomulin  Female           3          17          0
# 229      b742    Capomulin    Male           7          21          0
# ...       ...          ...     ...         ...         ...        ...
# 1854     s710    Capomulin  Female           1          23         45
# 1859     j119    Capomulin  Female           7          23         45
# 1878     i557    Capomulin  Female           1          24         45
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
Avg_tumor = filter_merge_df_cap.groupby(['Mouse ID']).mean()["Tumor Volume (mm3)"]
Avg_tumor
# Out:
# Mouse ID
# b128    41.963636
# b742    40.083699
# f966    36.505973
# g288    41.990097
# g316    44.613344
# i557    44.805810
# i738    39.141053
# j119    44.465236
# j246    43.216925
# l509    44.434474
# l897    42.507261
# m601    34.847470
# m957    39.049816
# r157    45.798970
# r554    36.509212
# r944    43.367364
# s185    34.559143
# s710    42.803733
# t565    39.328725
# u364    39.887495
# v923    41.581595
# w150    41.384825
# w914    41.352452
# x401    36.182040
# y793    38.506829
# Name: Tumor Volume (mm3), dtype: float64

# %%
mouse_weight = filter_merge_df_cap.groupby(['Mouse ID']).mean()["Weight (g)"]
mouse_weight
# Out:
# Mouse ID
# b128    22.0
# b742    21.0
# f966    17.0
# g288    19.0
# g316    22.0
# i557    24.0
# i738    20.0
# j119    23.0
# j246    21.0
# l509    21.0
# l897    19.0
# m601    17.0
# m957    19.0
# r157    25.0
# r554    17.0
# r944    25.0
# s185    17.0
# s710    23.0
# t565    17.0
# u364    17.0
# v923    21.0
# w150    23.0
# w914    21.0
# x401    15.0
# y793    17.0
# Name: Weight (g), dtype: float64

# %%
avg_tumor_and_weight_df = pd.DataFrame({"Weight (g)": mouse_weight, "Average Tumor Volume (mm3)": Avg_tumor})
avg_tumor_and_weight_df
# Out:
#           Weight (g)  Average Tumor Volume (mm3)
# Mouse ID
# b128            22.0                   41.963636
# b742            21.0                   40.083699
# f966            17.0                   36.505973
# g288            19.0                   41.990097
# g316            22.0                   44.613344
# i557            24.0                   44.805810
# i738            20.0                   39.141053
# j119            23.0                   44.465236
# j246            21.0                   43.216925
# l509            21.0                   44.434474
# l897            19.0                   42.507261
# m601            17.0                   34.847470
# m957            19.0                   39.049816
# r157            25.0                   45.798970
# r554            17.0                   36.509212
# r944            25.0                   43.367364
# s185            17.0                   34.559143
# s710            23.0                   42.803733
# ...

# %%
avg_tumor_and_weight_df.plot.scatter(x="Weight (g)", y="Average Tumor Volume (mm3)")
# Out:
# <AxesSubplot:xlabel='Weight (g)', ylabel='Average Tumor Volume (mm3)'>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
